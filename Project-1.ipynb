# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# Out:
# Running cells with 'Python 3.8.2 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# !pip install sklearn

# %% [markdown]
# Data: https://ticas.org/interactive-map/

# %%
# !pip install openpyxl

# %%
df = pd.read_csv('/Users/shegavala/Desktop/data/TICAS.org-State-Data-2020.csv')

# %%
df.head()
# Out:
#         State Average Debt of Graduates (2019-20)  Average Debt Rank  \
# 0     Alabama                            $30,996                  15
# 1      Alaska                            $26,356                  38
# 2     Arizona                            $24,298                  45
# 3    Arkansas                            $27,319                  32
# 4  California                            $21,125                  49
#
#   Percent of Graduates with Debt (2019-20)  Percent with Debt Rank  \
# 0                                      51%                      38
# 1                                      47%                      42
# 2                                      47%                      42
# 3                                      54%                      32
# 4                                      46%                      46
#
#    Usable Institutions (BA-Granting)  \
# 0                                 16
# 1                                  3
# ...

# %%
sorted_by_debt = df.sort_values(["Average Debt of Graduates (2019-20)"], ascending=False)

# %%
sorted_by_debt[:5]
# Out:
#             State Average Debt of Graduates (2019-20)  Average Debt Rank  \
# 29  New Hampshire                            $39,928                   1
# 7        Delaware                            $39,705                   2
# 38   Pennsylvania                            $39,375                   3
# 39   Rhode Island                            $36,791                   4
# 6     Connecticut                            $35,853                   5
#
#    Percent of Graduates with Debt (2019-20)  Percent with Debt Rank  \
# 29                                      70%                       2
# 7                                       60%                      12
# 38                                      64%                       5
# 39                                      64%                       5
# 6                                       57%                      21
#
#     Usable Institutions (BA-Granting)  \
# 29                                  9
# ...

# %%
sorted_by_debt = df.sort_values(["Average Debt of Graduates (2019-20)"],)

# %%
sorted_by_debt[:5]
# Out:
#          State Average Debt of Graduates (2019-20)  Average Debt Rank  \
# 44        Utah                            $18,344                  51
# 31  New Mexico                            $20,868                  50
# 4   California                            $21,125                  49
# 28      Nevada                            $21,357                  48
# 50     Wyoming                            $23,510                  47
#
#    Percent of Graduates with Debt (2019-20)  Percent with Debt Rank  \
# 44                                      39%                      51
# 31                                      45%                      49
# 4                                       46%                      46
# 28                                      46%                      46
# 50                                      48%                      41
#
#     Usable Institutions (BA-Granting)  \
# 44                                  8
# 31                                  5
# ...

# %%
sorted_by_debt = df.sort_values(["Percent of Graduates with Debt (2019-20)"])

# %%
sorted_by_debt[:5]
# Out:
#                    State Average Debt of Graduates (2019-20)  \
# 44                  Utah                            $18,344
# 31            New Mexico                            $20,868
# 11                Hawaii                            $24,926
# 4             California                            $21,125
# 8   District of Columbia                            $32,966
#
#     Average Debt Rank Percent of Graduates with Debt (2019-20)  \
# 44                 51                                      39%
# 31                 50                                      45%
# 11                 43                                      45%
# 4                  49                                      46%
# 8                   9                                      46%
#
#     Percent with Debt Rank  Usable Institutions (BA-Granting)  \
# 44                      51                                  8
# 31                      49                                  5
# ...

# %%
sorted_by_debt = df.sort_values(["Tuition and Fees (in-district/in-state)"])

# %%
sorted_by_debt[:5]
# Out:
#            State Average Debt of Graduates (2019-20)  Average Debt Rank  \
# 12         Idaho                            $24,983                  42
# 50       Wyoming                            $23,510                  47
# 44          Utah                            $18,344                  51
# 34  North Dakota                            $31,939                  14
# 31    New Mexico                            $20,868                  50
#
#    Percent of Graduates with Debt (2019-20)  Percent with Debt Rank  \
# 12                                      58%                      18
# 50                                      48%                      41
# 44                                      39%                      51
# 34                                      66%                       3
# 31                                      45%                      49
#
#     Usable Institutions (BA-Granting)  \
# 12                                  8
# 50                                  1
# ...

# %%
df.columns
# Out:
# Index(['State', 'Average Debt of Graduates (2019-20)', 'Average Debt Rank',
#        'Percent of Graduates with Debt (2019-20)', 'Percent with Debt Rank',
#        'Usable Institutions (BA-Granting)',
#        'Percent of Graduates at Schools with Usable Data',
#        'Nonfederal debt of graduates, as percent of total debt',
#        ' Fall enrollment - Undergraduate total (IPEDS) ',
#        'Tuition and Fees (in-district/in-state)',
#        'Total Cost of Attendance (on-campus)',
#        'Percent of Institutional Grants that are Need-Based',
#        'Undergraduates who received Pell Grants (%) (2019-20)'],
#       dtype='object')

# %%
df.shape
# Out:
# (51, 13)

# %%
df.dtypes
# Out:
# State                                                      object
# Average Debt of Graduates (2019-20)                         int64
# Average Debt Rank                                           int64
# Percent of Graduates with Debt (2019-20)                  float64
# Percent with Debt Rank                                      int64
# Usable Institutions (BA-Granting)                           int64
# Percent of Graduates at Schools with Usable Data          float64
# Nonfederal debt of graduates, as percent of total debt    float64
#  Fall enrollment - Undergraduate total (IPEDS)              int64
# Tuition and Fees (in-district/in-state)                     int64
# Total Cost of Attendance (on-campus)                        int64
# Percent of Institutional Grants that are Need-Based       float64
# Undergraduates who received Pell Grants (%) (2019-20)     float64
# dtype: object

# %%
df['State']
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
df.describe()
# Out:
#        Average Debt of Graduates (2019-20)  Average Debt Rank  \
# count                            51.000000          51.000000
# mean                          29096.196078          26.000000
# std                            4735.492975          14.866069
# min                           18344.000000           1.000000
# 25%                           26320.000000          13.500000
# 50%                           28713.000000          26.000000
# 75%                           31975.500000          38.500000
# max                           39928.000000          51.000000
#
#        Percent of Graduates with Debt (2019-20)  Percent with Debt Rank  \
# count                                 51.000000               51.000000
# mean                                   0.556471               25.039216
# std                                    0.071157               14.919733
# min                                    0.390000                1.000000
# ...

# %% [markdown]
# Student debt by State
# The top highest avarage debt by state
# The top lowest avarage dept by state
